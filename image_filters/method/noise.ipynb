# %%
import numpy as np
import random
import cv2
import matplotlib.pyplot as plt

def sp_noise(image,prob):
    '''
    Add salt and pepper noise to image
    prob: Probability of the noise
    '''
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output

# %%
#read image from storage
img = cv2.imread('/home/scyeroux/python/image_processing-basics/images/Lenna.png')
#convert to RGB channel
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
histr = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histr)
plt.show()

# %%
noise_img = sp_noise(img,0.3)
plt.imshow(noise_img)
noise_img = cv2.cvtColor(noise_img,cv2.COLOR_BGR2RGB)
cv2.imwrite('/home/scyeroux/python/image_processing-basics/images/Lenna-noise.png', noise_img)
# Out:
# True

# %%
histr = cv2.calcHist([noise_img],[0],None,[256],[0,256])
plt.plot(histr)
plt.show()
