# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('/home/scyeroux/python/image_processing-basics/images/Lenna.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

increase = 100

v = img
v = np.where(v <= 255 - increase, v + increase, 255)
brighten_img = v

# image_brighten = cv2.cvtColor(img, cv2.COLOR_HSV2BGR)


plt.imshow(brighten_img)
